# %% [markdown]
# ### **Wordnet Lemmatizer**
#
# Lemmatization technique is like stemming. The output we will get after lemmatization is called ‘lemma’, which is a root word rather than root stem, the output of stemming. After lemmatization, we will be getting a valid word that means the same thing.
#
# NLTK provides WordNetLemmatizer class which is a thin wrapper around the wordnet corpus. This class uses morphy() function to the WordNet CorpusReader class to find a lemma. Let us understand it with an example –

# %%
##Q&A chatbots, text summerizers
from nltk.stem import WordNetLemmatizer

import nltk

nltk.download('wordnet')
nltk.download('omw-1.4')   # Recommended for better lemmatization
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rashi\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\rashi\AppData\Roaming\nltk_data...
# True

# %%
lemmatizer = WordNetLemmatizer()

# %%
'''
POS - Noun - n
verb - v
adjective - a
adverb - r
'''
lemmatizer.lemmatize("going", pos = 'v')
# Out:
# 'go'

# %%
words = ["eating", "eats", "writing", "writes", "eaten", "programming", "programs", "history", "finally", "finalize"]

# %%
for word in words:
    print(word+"--->"+lemmatizer.lemmatize(word, pos = 'v'))
# Out:
# eating--->eat
# eats--->eat
# writing--->write
# writes--->write
# eaten--->eat
# programming--->program
# programs--->program
# history--->history
# finally--->finally
# finalize--->finalize

# %%
lemmatizer.lemmatize('fairly', pos = 'r'), lemmatizer.lemmatize('sportingly', pos = 'r'), lemmatizer.lemmatize('goes', pos = 'v')
# Out:
# ('fairly', 'sportingly', 'go')
